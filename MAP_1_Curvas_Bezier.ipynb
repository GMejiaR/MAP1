# %% [markdown]
# <a href="https://colab.research.google.com/github/GMejiaR/MAP1/blob/main/MAP_1_Curvas_Bezier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![MAP1.png](https://drive.google.com/uc?export=view&id=1ieqFIi_PJWMdQBT9w0K9zykhpeq8eKNB)

# %% [markdown]
# # 1. Introducción.
#
# Una curva de Bézier está determinada mediante cuatro **puntos de control**, $P_0(x_0, y_0)$, $P_1(x_1, y_1)$, $P_2(x_2, y_2)$ y $P_3(x_3, y_3)$. Dicha curva se define mediante las siguientes **ecuaciones paramétricas**:
#
# $$x=x_0\, (1-t)^3 + 3x_1\, t(1-t)^2 + 3x_2\, t^2(1-t) + x_3\, t^3$$
# $$y=y_0\, (1-t)^3 + 3y_1\, t(1-t)^2 + 3y_2t^2(1-t) + y_3 \, t^3,$$
#
#
# en donde $0\leq t \leq 1$.  Observe que cuando $t = 0$, se tiene que $(x, y) = P_0(x_0, y_0)$ y cuando $t = 1$ se tiene $(x, y) = P_3(x_3, y_3)$. Por lo tanto,  dicha curva inicia en $P_0$ y termina en $P_3$.	La siguiente figura ilustra algunas curvas de Bézier con los puntos de control ilustrados, note como la curvas se ajustan a medida que se varían dichos puntos de control.
#
# ![MAP1.png](https://drive.google.com/uc?export=view&id=1TI7KnfK8pVAnCaxyx49KZqwPIC47NuEv)

# %% [markdown]
# ## 1.1. Ejemplo de Curvas de Bezier con Python
# Librerias necesarias para gráficas
#
#
# ```
# import numpy as np
# import matplotlib.pyplot as plt
# ```
# La restricción del intervalo para el parámetro $t$ se puede realizar con la siguiente linea de código:
#
#
#
# ```
# t = np.linspace(0,1,100)
# ```
#
# donde el intervalo mostrado es $0\leq t \leq 1$ con uso de 100 valores de muestra en el intervalo. Los puntos de control para la curva de Bezier se definen en las siguientes lineas:
#
#
#
# *   $P_0(x_0,y_0)$:
#
#
# ```
# x_0 = -3
# y_0 = 2
# ```
#
# *   $P_1(x_1,y_1)$:
#
#
# ```
# x_1 = 2
# y_1 = 5
# ```
#
# *   $P_2(x_2,y_2)$:
#
#
# ```
# x_2 = 5
# y_2 = 5
# ```
#
# *   $P_3(x_3,y_3)$:
#
#
# ```
# x_3 = 6
# y_3 = -1
# ```
#
# Las ecuaciones paramétricas para la Curva de Bezier vistas en la introducción se definen como:
#
#
# ```
# x = x_0*(1-t)**3 + 3*x_1*t*(1-t)**2 + 3*x_2*t**2*(1-t) + x_3*t**3
# y = y_0*(1-t)**3 + 3*y_1*t*(1-t)**2 + 3*y_2*t**2*(1-t) + y_3*t**3
# ```
#
# Para graficar la curva de Bezier anterior definida se utiliza la librería *Mathplotlib* de Python.
#
#
# ```
# plt.plot(x,y,c=(1,0.5,0.5),lw=4) + plt.plot(0,0,c=(1,0.5,0.5),lw=4)
# ```

# %% [markdown]
# ## 1.2. Simulación del Ejemplo
# Las anteriores lineas y definiciones las puede simular en la siguiente parte de código.

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0,1,100)

x_0 = -3
y_0 = 7
 
x_1 = 3
y_1 = 7

x_2 = 4
y_2 = 2

x_3 = 6
y_3 = -1

x = x_0*(1-t)**3 + 3*x_1*t*(1-t)**2 + 3*x_2*t**2*(1-t) + x_3*t**3
y = y_0*(1-t)**3 + 3*y_1*t*(1-t)**2 + 3*y_2*t**2*(1-t) + y_3*t**3


# Titulo de la gráfica y ejes


# Gráfica de los Puntos P0, P1, P2, P3  
x_puntos = [x_0,x_1,x_2,x_3] 
y_puntos = [y_0,y_1,y_2,y_3] 


# Curva de Bezier
#plt.xlim(0, 100)
#plt.ylim(0, 50);

f = plt.figure()
plt.title('Curva de Bezier') 
plt.xlabel('Eje x') 
plt.ylabel('Eje y') 
f.set_figwidth(20)
f.set_figheight(10)
plt.plot(x_puntos, y_puntos, color='green', linestyle='dashed', linewidth = 3, 
         marker='o', markerfacecolor='blue', markersize = 12) 
plt.plot(x,y,c=(1,0.5,0.5),lw=4)
#plt.plot(x,y,c=(1,0.5,0.5),lw=4)
plt.show()

# %% [markdown]
# Adicional usted encuentra como colocar nombre a su gráfica, etiqueta de ejes y como graficar rectas entre puntos.

# %% [markdown]
# # 2. Guía Práctica - Parte 1

# %% [markdown]
# # New Section

# %% [markdown]
# 1.   Grafique la curva de Bézier generada por puntos de control $P_0(4,1)$, $P_1(28, 48)$, $P_2(50,42)$ y $P_3(40,5)$.

# %%
###### Agregue las lineas de código que considere necesarias para este inciso.
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0,1,100)

x_0 = 4
y_0 = 1

x_1 = 28
y_1 = 48

x_2 = 50
y_2 = 42

x_3 = 40
y_3 = 5

x = x_0*(1-t)**3 + 3*x_1*t*(1-t)**2 + 3*x_2*t**2*(1-t) + x_3*t**3
y = y_0*(1-t)**3 + 3*y_1*t*(1-t)**2 + 3*y_2*t**2*(1-t) + y_3*t**3

f = plt.figure()
plt.title('Curva de Bezier') 
plt.xlabel('Eje x') 
plt.ylabel('Eje y') 
f.set_figwidth(20)
f.set_figheight(10)
plt.plot(x,y,c=(1,0.5,0.5),lw=4)
plt.show()
######

# %% [markdown]
# 2.   En la misma gráfica, trace los segmentos de recta $\overline{P_0P_1}$, $\overline{P_1P_2}$
# 		y $\overline{P_2P_3}$.
# 		Notar como los puntos de control medios $P_1$ y $P_2$ no están sobre la curva.
# 		La curva inicia en $P_0$, se dirige hacia $P_1$ y $P_2$ sin alcanzarlos y termina
# 		en $P_3$.

# %%
###### Agregue las lineas de código que considere necesarias para este inciso.
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0,1,100)

x_0 = 4
y_0 = 1

x_1 = 28
y_1 = 48

x_2 = 50
y_2 = 42

x_3 = 40
y_3 = 5

x = x_0*(1-t)**3 + 3*x_1*t*(1-t)**2 + 3*x_2*t**2*(1-t) + x_3*t**3
y = y_0*(1-t)**3 + 3*y_1*t*(1-t)**2 + 3*y_2*t**2*(1-t) + y_3*t**3

x_puntos = [x_0,x_1,x_2,x_3] 
y_puntos = [y_0,y_1,y_2,y_3] 

f = plt.figure()
plt.title('Curva de Bezier') 
plt.xlabel('Eje x') 
plt.ylabel('Eje y') 
f.set_figwidth(20)
f.set_figheight(10)
plt.plot(x_puntos, y_puntos, color='black', linestyle='-', linewidth = 1, 
         marker='s', markerfacecolor='black', markersize = 6) 
plt.plot(x,y,c=(1,0.5,0.5),lw=4)
plt.show()

######

# %% [markdown]
# 3.   Algunas impresoras láser usan las curvas de Bézier para representar letras y otros símbolos. Experimente con puntos de control hasta que encuentre una curva de Bézier que dé una representación razonable de la letra $C$.

# %%
###### Agregue las lineas de código que considere necesarias para este inciso.
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0,1,100)

x_0 = 3
y_0 = 1

x_1 = 1
y_1 = 1

x_2 = 1
y_2 = 4

x_3 = 3
y_3 = 4

x_4 = 3
y_4 = 2

x_5 = 2
y_5 = 2

x_6 = 2
y_6 = 3

x_7 = 3
y_7 = 3

x_8 = 3
y_8 = 4

x_9 = 3
y_9 = 3

x_10 = 3
y_10 = 3

x_11 = 3
y_11 = 3

x_12 = 3
y_12 = 2

x_13 = 3
y_13 = 1

x_14 = 3
y_14 = 1

x_15 = 3
y_15 = 1

x = x_0*(1-t)**3 + 3*x_1*t*(1-t)**2 + 3*x_2*t**2*(1-t) + x_3*t**3
y = y_0*(1-t)**3 + 3*y_1*t*(1-t)**2 + 3*y_2*t**2*(1-t) + y_3*t**3

x2 = x_4*(1-t)**3 + 3*x_5*t*(1-t)**2 + 3*x_6*t**2*(1-t) + x_7*t**3
y2 = y_4*(1-t)**3 + 3*y_5*t*(1-t)**2 + 3*y_6*t**2*(1-t) + y_7*t**3

x3 = x_8*(1-t)**3 + 3*x_9*t*(1-t)**2 + 3*x_10*t**2*(1-t) + x_11*t**3
y3 = y_8*(1-t)**3 + 3*y_9*t*(1-t)**2 + 3*y_10*t**2*(1-t) + y_11*t**3

x4 = x_12*(1-t)**3 + 3*x_13*t*(1-t)**2 + 3*x_14*t**2*(1-t) + x_15*t**3
y4 = y_12*(1-t)**3 + 3*y_13*t*(1-t)**2 + 3*y_14*t**2*(1-t) + y_15*t**3

#x_puntos = [x_0,x_1,x_2,x_3] 
#y_puntos = [y_0,y_1,y_2,y_3] 

f = plt.figure()
plt.title('Curva de Bezier') 
plt.xlabel('Eje x') 
plt.ylabel('Eje y') 
f.set_figwidth(10)
f.set_figheight(15)
#plt.plot(x_puntos, y_puntos, color='black', linestyle='-', linewidth = 1, 
         #marker='s', markerfacecolor='black', markersize = 6) 
plt.plot(x,y,c=('blue'),lw=4)
plt.plot(x2,y2,c=('blue'),lw=4)
plt.plot(x3,y3,c=('blue'),lw=4)
plt.plot(x4,y4,c=('blue'),lw=4)
plt.show()


######

# %% [markdown]
# 4.   Se pueden representar formas más complicadas al unir dos o más curvas de Bézier. Suponga que la primera curva de Bézier tienen puntos de control $P_0$, $P_1$, $P_2$ y $P_3$ y la segunda tiene puntos de control $P_3$, $P_4$, $P_5$ y $P_6$. Si desea unir estos dos trozos
#  de manera *suave*, entonces las rectas tangentes en $P_3$ debe corresponderse y, por tanto, los puntos $P_2$, $P_3$ y $P_4$ tiene que estar sobre esta recta tangente común.
#
#
#  Grafique las curvas de Bézier que considere necesarias para escribir el **nombre** o **apellido** de algún matemático famoso *(con un mínimo de 6 letras)*. No olvide agregar dichas ecuaciones y	su gráfica al reporte.

# %%
###### Agregue las lineas de código que considere necesarias para este inciso.
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors

t = np.linspace(0,1,100)

x_0 = 0.5
y_0 = 0

x_1 = 0.5
y_1 = 0

x_2 = 0.5
y_2 = 0

x_3 = 0.5
y_3 = 7

x_4 = 3
y_4 = 7

x_5 = 0.5
y_5 = 7

x_6 = 2
y_6 = 7

x_7 = 0.5
y_7 = 7

x_8 = 3
y_8 = 0

x_9 = 3
y_9 = 0

x_10 = 1
y_10 = 0

x_11 = 0.5
y_11 = 0

x_12 = 3
y_12 = 1

x_13 = 3
y_13 = 0

x_14 = 3
y_14 = 0

x_15 = 3
y_15 = 0

x_16 = 3
y_16 = 1

x_17 = 3
y_17 = 1

x_18 = 1.5
y_18 = 1

x_19 = 1.5
y_19 = 1

x_20 = 3
y_20 = 7

x_21 = 3
y_21 = 6

x_22 = 3
y_22 = 6

x_23 = 3
y_23 = 6

x_24 = 3
y_24 = 6

x_25 = 3
y_25 = 6

x_26 = 1.5
y_26 = 6

x_27 = 1.5
y_27 = 6

x_28 = 1.5
y_28 = 3

x_29 = 1.5
y_29 = 1

x_30 = 1.5
y_30 = 1

x_31 = 1.5
y_31 = 1

x_32 = 1.5
y_32 = 4

x_33 = 1.5
y_33 = 6

x_34 = 1.5
y_34 = 6

x_35 = 1.5
y_35 = 6

x_36 = 1.5
y_36 = 3

x_37 = 1.5
y_37 = 3

x_38 = 2.5
y_38 = 3

x_39 = 2.5
y_39 = 3

x_40 = 1.5
y_40 = 4

x_41 = 1.5
y_41 = 4

x_42 = 2.5
y_42 = 4

x_43 = 2.5
y_43 = 4

x_44 = 2.5
y_44 = 3

x_45 = 2.5
y_45 = 4

x_46 = 2.5
y_46 = 3

x_47 = 2.5
y_47 = 4

x_48 = 3.1
y_48 = 7

x_49 = 3.1
y_49 = -2.5

x_50 = 6
y_50 = -2.5

x_51 = 6
y_51 = 7

x_52 = 4.1
y_52 = 7

x_53 = 4.1
y_53 = 0

x_54 = 5
y_54 = 0

x_55 = 5
y_55 = 7

x_56 = 3.1
y_56 = 7

x_57 = 3.1
y_57 = 7

x_58 = 4.1
y_58 = 7

x_59 = 4.1
y_59 = 7

x_60 = 6
y_60 = 7

x_61 = 5
y_61 = 7

x_62 = 6
y_62 = 7

x_63 = 5
y_63 = 7

x_64 = 10
y_64 = 0

x_65 = 5
y_65 = 0

x_66 = 5
y_66 = 7

x_67 = 10
y_67 = 7

x_68 = 10
y_68 = 6

x_69 = 6.5
y_69 = 6

x_70 = 6.5
y_70 = 1

x_71 = 10
y_71 = 1

x_72 = 10
y_72 = 0

x_73 = 10
y_73 = 1

x_74 = 10
y_74 = 1

x_75 = 10
y_75 = 1

x_76 = 10
y_76 = 6

x_77 = 10
y_77 = 7

x_78 = 10
y_78 = 7

x_79 = 10
y_79 = 7

x_80 = 10.7
y_80 = 0

x_81 = 10.7
y_81 = 7

x_82 = 10.7
y_82 = 7

x_83 = 10.7
y_83 = 7

x_84 = 12
y_84 = 1

x_85 = 12
y_85 = 7

x_86 = 12
y_86 = 7

x_87 = 12
y_87 = 7

x_88 = 10.7 
y_88 = 7

x_89 = 10.7 
y_89 = 7

x_90 = 12
y_90 = 7

x_91 = 12
y_91 = 7

x_92 = 12 
y_92 = 1

x_93 = 12 
y_93 = 1

x_94 = 14
y_94 = 1

x_95 = 14
y_95 = 1

x_96 = 11
y_96 = 0

x_97 = 11
y_97 = 0

x_98 = 14
y_98 = 0

x_99 = 14
y_99 = 0

x_100 = 14
y_100 = 0

x_101 = 14
y_101 = 0

x_102 = 14
y_102 = 1

x_103 = 14
y_103= 1

x_104 = 10.7
y_104 = 0

x_105 = 10.7
y_105 = 0

x_106 = 14
y_106 = 0

x_107 = 14
y_107= 0

x_108 = 14.5
y_108 = 0

x_109 = 14.5
y_109 = 7

x_110 = 14.5
y_110 = 7

x_111 = 14.5
y_111 = 7

x_112 = 16
y_112 = 7

x_113 = 16
y_113 = 0

x_114 = 16
y_114 = 0

x_115 = 16
y_115 = 0

x_116 = 14.5
y_116 = 7

x_117 = 16
y_117 = 7

x_118 = 16
y_118 = 7

x_119 = 16
y_119 = 7

x_120 = 14.5
y_120 = 0

x_121 = 16
y_121 = 0

x_122 = 16
y_122 = 0

x_123 = 16
y_123 = 0

x_124 = 16.5
y_124 = 0

x_125 = 16.5
y_125 = 7

x_126 = 16.5
y_126 = 7

x_127 = 16.5
y_127 = 7

x_128 = 16.5
y_128 = 0

x_129 = 21.5
y_129 = 0

x_130 = 21.5
y_130 = 7

x_131 = 16.5
y_131 = 7

x_132 = 17.5
y_132 = 2

x_133 = 17.5
y_133 = 5

x_134 = 17.5
y_134 = 5

x_135 = 17.5
y_135 = 5

x_136 = 17.5
y_136 = 2

x_137 = 19.5
y_137 = 2

x_138 = 19.5
y_138 = 5

x_139 = 17.5
y_139 = 5

x_140 = 20.8
y_140 = 0

x_141 = 20.8
y_141 = 0
 
x_142 = 20.8
y_142 = 7

x_143 = 20.8
y_143 = 7

x_144 = 20.8
y_144 = 0
 
x_145 = 20.8
y_145 = 0

x_146 = 23.8
y_146 = 0

x_147 = 23.8
y_147 = 0

x_148 = 23.8
y_148 = 0

x_149 = 23.8 
y_149 = 0

x_150 = 23.8
y_150 = 1

x_151 = 23.8
y_151 = 1

x_152 = 23.8
y_152 = 1

x_153 = 23.8 
y_153 = 1

x_154 = 22.5
y_154 = 1

x_155 = 22.5
y_155 = 1

x_156 = 22.5
y_156 = 1

x_157 = 22.5 
y_157 = 1

x_158 = 22.5
y_158 = 3

x_159 = 22.5
y_159 = 3

x_160 = 22.5
y_160 = 3

x_161 =  22.5
y_161 = 3

x_162 = 23.5
y_162 = 3

x_163 = 23.5
y_163 = 3

x_164 = 23.5
y_164 = 3

x_165 =  23.5
y_165 = 3

x_166 = 23.5
y_166 = 4

x_167 = 23.5
y_167 = 4

x_168 = 22.5
y_168 = 4

x_169 =  22.5
y_169 = 4

x_170 = 23.5
y_170 = 4

x_171 = 23.5
y_171 = 4

x_172 = 22.5
y_172 = 4

x_173 = 22.5 
y_173 = 4

x_174 = 22.5
y_174 = 6

x_175 = 22.5
y_175 = 6

x_176 = 22.5
y_176 = 6

x_177 = 23.8
y_177 = 6

x_178 = 23.8
y_178 = 6

x_179 = 23.8
y_179 = 6

x_180 = 20.8
y_180 = 7

x_181 = 23.8
y_181 = 7

x_182 = 23.8
y_182 = 7

x_183 = 23.8
y_183 = 7

x_184 = 23.8
y_184 = 6

x_185 = 23.8
y_185 = 6

x_186 = 23.8
y_186 = 7

x_187 = 23.8
y_187 = 7

x_188 = 24.5
y_188 = 1

x_189 = 24.5
y_189 = 0

x_190 = 25
y_190 = 0

x_191 = 26
y_191 = 0

x_192 = 26
y_192 = 3.5

x_193 = 28.1
y_193 = 3.5

x_194 = 28.1
y_194 = 0

x_195 = 26
y_195 = 0

x_196 = 26
y_196 = 3.5

x_197 = 23.5
y_197 = 3.6

x_198 = 24
y_198 = 7

x_199 = 26
y_199 = 7

x_200 = 27.5
y_200 = 6

x_201 = 27.5
y_201 = 7.2

x_202 = 26.5
y_202 = 7

x_203 = 26
y_203 = 7

x_204 = 27.5
y_204 = 6

x_205 = 27.5
y_205 = 5.6

x_206 = 27.5
y_206 = 5.6

x_207 = 27.5
y_207 = 5.6

x_208 = 27.5
y_208 = 5.6

x_209 = 26.6
y_209 = 5.6

x_210 = 26.6
y_210 = 5.6

x_211 = 26.6
y_211 = 5.6

x_212 = 24.5
y_212 = 1

x_213 = 25.3
y_213 = 1

x_214 = 25.3
y_214 = 1

x_215 = 25.3
y_215 = 1

x = x_0*(1-t)**3 + 3*x_1*t*(1-t)**2 + 3*x_2*t**2*(1-t) + x_3*t**3
y = y_0*(1-t)**3 + 3*y_1*t*(1-t)**2 + 3*y_2*t**2*(1-t) + y_3*t**3

x2 = x_4*(1-t)**3 + 3*x_5*t*(1-t)**2 + 3*x_6*t**2*(1-t) + x_7*t**3
y2 = y_4*(1-t)**3 + 3*y_5*t*(1-t)**2 + 3*y_6*t**2*(1-t) + y_7*t**3

x3 = x_8*(1-t)**3 + 3*x_9*t*(1-t)**2 + 3*x_10*t**2*(1-t) + x_11*t**3
y3 = y_8*(1-t)**3 + 3*y_9*t*(1-t)**2 + 3*y_10*t**2*(1-t) + y_11*t**3

x4 = x_12*(1-t)**3 + 3*x_13*t*(1-t)**2 + 3*x_14*t**2*(1-t) + x_15*t**3
y4 = y_12*(1-t)**3 + 3*y_13*t*(1-t)**2 + 3*y_14*t**2*(1-t) + y_15*t**3

x5 = x_16*(1-t)**3 + 3*x_17*t*(1-t)**2 + 3*x_18*t**2*(1-t) + x_19*t**3
y5 = y_16*(1-t)**3 + 3*y_17*t*(1-t)**2 + 3*y_18*t**2*(1-t) + y_19*t**3

x6 = x_20*(1-t)**3 + 3*x_21*t*(1-t)**2 + 3*x_22*t**2*(1-t) + x_23*t**3
y6 = y_20*(1-t)**3 + 3*y_21*t*(1-t)**2 + 3*y_22*t**2*(1-t) + y_23*t**3

x7 = x_24*(1-t)**3 + 3*x_25*t*(1-t)**2 + 3*x_26*t**2*(1-t) + x_27*t**3
y7 = y_24*(1-t)**3 + 3*y_25*t*(1-t)**2 + 3*y_26*t**2*(1-t) + y_27*t**3

x8 = x_28*(1-t)**3 + 3*x_29*t*(1-t)**2 + 3*x_30*t**2*(1-t) + x_31*t**3
y8 = y_28*(1-t)**3 + 3*y_29*t*(1-t)**2 + 3*y_30*t**2*(1-t) + y_31*t**3

x9 = x_32*(1-t)**3 + 3*x_33*t*(1-t)**2 + 3*x_34*t**2*(1-t) + x_35*t**3
y9 = y_32*(1-t)**3 + 3*y_33*t*(1-t)**2 + 3*y_34*t**2*(1-t) + y_35*t**3

x10 = x_36*(1-t)**3 + 3*x_37*t*(1-t)**2 + 3*x_38*t**2*(1-t) + x_39*t**3
y10 = y_36*(1-t)**3 + 3*y_37*t*(1-t)**2 + 3*y_38*t**2*(1-t) + y_39*t**3

x11 = x_40*(1-t)**3 + 3*x_41*t*(1-t)**2 + 3*x_42*t**2*(1-t) + x_43*t**3
y11 = y_40*(1-t)**3 + 3*y_41*t*(1-t)**2 + 3*y_42*t**2*(1-t) + y_43*t**3

x12 = x_44*(1-t)**3 + 3*x_45*t*(1-t)**2 + 3*x_46*t**2*(1-t) + x_47*t**3
y12 = y_44*(1-t)**3 + 3*y_45*t*(1-t)**2 + 3*y_46*t**2*(1-t) + y_47*t**3

x13 = x_48*(1-t)**3 + 3*x_49*t*(1-t)**2 + 3*x_50*t**2*(1-t) + x_51*t**3
y13 = y_48*(1-t)**3 + 3*y_49*t*(1-t)**2 + 3*y_50*t**2*(1-t) + y_51*t**3

x14 = x_52*(1-t)**3 + 3*x_53*t*(1-t)**2 + 3*x_54*t**2*(1-t) + x_55*t**3
y14 = y_52*(1-t)**3 + 3*y_53*t*(1-t)**2 + 3*y_54*t**2*(1-t) + y_55*t**3

x15 = x_56*(1-t)**3 + 3*x_57*t*(1-t)**2 + 3*x_58*t**2*(1-t) + x_59*t**3
y15 = y_56*(1-t)**3 + 3*y_57*t*(1-t)**2 + 3*y_58*t**2*(1-t) + y_59*t**3

x16 = x_60*(1-t)**3 + 3*x_61*t*(1-t)**2 + 3*x_62*t**2*(1-t) + x_63*t**3
y16 = y_60*(1-t)**3 + 3*y_61*t*(1-t)**2 + 3*y_62*t**2*(1-t) + y_63*t**3

x17 = x_64*(1-t)**3 + 3*x_65*t*(1-t)**2 + 3*x_66*t**2*(1-t) + x_67*t**3
y17 = y_64*(1-t)**3 + 3*y_65*t*(1-t)**2 + 3*y_66*t**2*(1-t) + y_67*t**3

x18 = x_68*(1-t)**3 + 3*x_69*t*(1-t)**2 + 3*x_70*t**2*(1-t) + x_71*t**3
y18 = y_68*(1-t)**3 + 3*y_69*t*(1-t)**2 + 3*y_70*t**2*(1-t) + y_71*t**3

x19 = x_72*(1-t)**3 + 3*x_73*t*(1-t)**2 + 3*x_74*t**2*(1-t) + x_75*t**3
y19 = y_72*(1-t)**3 + 3*y_73*t*(1-t)**2 + 3*y_74*t**2*(1-t) + y_75*t**3

x20 = x_76*(1-t)**3 + 3*x_77*t*(1-t)**2 + 3*x_78*t**2*(1-t) + x_79*t**3
y20 = y_76*(1-t)**3 + 3*y_77*t*(1-t)**2 + 3*y_78*t**2*(1-t) + y_79*t**3

x21 = x_80*(1-t)**3 + 3*x_81*t*(1-t)**2 + 3*x_82*t**2*(1-t) + x_83*t**3
y21 = y_80*(1-t)**3 + 3*y_81*t*(1-t)**2 + 3*y_82*t**2*(1-t) + y_83*t**3

x22 = x_84*(1-t)**3 + 3*x_85*t*(1-t)**2 + 3*x_86*t**2*(1-t) + x_87*t**3
y22 = y_84*(1-t)**3 + 3*y_85*t*(1-t)**2 + 3*y_86*t**2*(1-t) + y_87*t**3

x23 = x_88*(1-t)**3 + 3*x_89*t*(1-t)**2 + 3*x_90*t**2*(1-t) + x_91*t**3
y23 = y_88*(1-t)**3 + 3*y_89*t*(1-t)**2 + 3*y_90*t**2*(1-t) + y_91*t**3

x24 = x_92*(1-t)**3 + 3*x_93*t*(1-t)**2 + 3*x_94*t**2*(1-t) + x_95*t**3
y24 = y_92*(1-t)**3 + 3*y_93*t*(1-t)**2 + 3*y_94*t**2*(1-t) + y_95*t**3

x25 = x_96*(1-t)**3 + 3*x_97*t*(1-t)**2 + 3*x_98*t**2*(1-t) + x_99*t**3
y25 = y_96*(1-t)**3 + 3*y_97*t*(1-t)**2 + 3*y_98*t**2*(1-t) + y_99*t**3

x25 = x_100*(1-t)**3 + 3*x_101*t*(1-t)**2 + 3*x_102*t**2*(1-t) + x_103*t**3
y25 = y_100*(1-t)**3 + 3*y_101*t*(1-t)**2 + 3*y_102*t**2*(1-t) + y_103*t**3

x26 = x_104*(1-t)**3 + 3*x_105*t*(1-t)**2 + 3*x_106*t**2*(1-t) + x_107*t**3
y26 = y_104*(1-t)**3 + 3*y_105*t*(1-t)**2 + 3*y_106*t**2*(1-t) + y_107*t**3

x27 = x_108*(1-t)**3 + 3*x_109*t*(1-t)**2 + 3*x_110*t**2*(1-t) + x_111*t**3
y27 = y_108*(1-t)**3 + 3*y_109*t*(1-t)**2 + 3*y_110*t**2*(1-t) + y_111*t**3

x28 = x_112*(1-t)**3 + 3*x_113*t*(1-t)**2 + 3*x_114*t**2*(1-t) + x_115*t**3
y28 = y_112*(1-t)**3 + 3*y_113*t*(1-t)**2 + 3*y_114*t**2*(1-t) + y_115*t**3

x29 = x_116*(1-t)**3 + 3*x_117*t*(1-t)**2 + 3*x_118*t**2*(1-t) + x_119*t**3
y29 = y_116*(1-t)**3 + 3*y_117*t*(1-t)**2 + 3*y_118*t**2*(1-t) + y_119*t**3

x30 = x_120*(1-t)**3 + 3*x_121*t*(1-t)**2 + 3*x_122*t**2*(1-t) + x_123*t**3
y30 = y_120*(1-t)**3 + 3*y_121*t*(1-t)**2 + 3*y_122*t**2*(1-t) + y_123*t**3

x31 = x_124*(1-t)**3 + 3*x_125*t*(1-t)**2 + 3*x_126*t**2*(1-t) + x_127*t**3
y31 = y_124*(1-t)**3 + 3*y_125*t*(1-t)**2 + 3*y_126*t**2*(1-t) + y_127*t**3

x32 = x_128*(1-t)**3 + 3*x_129*t*(1-t)**2 + 3*x_130*t**2*(1-t) + x_131*t**3
y32 = y_128*(1-t)**3 + 3*y_129*t*(1-t)**2 + 3*y_130*t**2*(1-t) + y_131*t**3

x33 = x_132*(1-t)**3 + 3*x_133*t*(1-t)**2 + 3*x_134*t**2*(1-t) + x_135*t**3
y33 = y_132*(1-t)**3 + 3*y_133*t*(1-t)**2 + 3*y_134*t**2*(1-t) + y_135*t**3

x34 = x_136*(1-t)**3 + 3*x_137*t*(1-t)**2 + 3*x_138*t**2*(1-t) + x_139*t**3
y34 = y_136*(1-t)**3 + 3*y_137*t*(1-t)**2 + 3*y_138*t**2*(1-t) + y_139*t**3

x35 = x_140*(1-t)**3 + 3*x_141*t*(1-t)**2 + 3*x_142*t**2*(1-t) + x_143*t**3
y35 = y_140*(1-t)**3 + 3*y_141*t*(1-t)**2 + 3*y_142*t**2*(1-t) + y_142*t**3

x36 = x_144*(1-t)**3 + 3*x_145*t*(1-t)**2 + 3*x_146*t**2*(1-t) + x_147*t**3
y36 = y_144*(1-t)**3 + 3*y_145*t*(1-t)**2 + 3*y_146*t**2*(1-t) + y_147*t**3

x37 = x_148*(1-t)**3 + 3*x_149*t*(1-t)**2 + 3*x_150*t**2*(1-t) + x_151*t**3
y37 = y_148*(1-t)**3 + 3*y_149*t*(1-t)**2 + 3*y_150*t**2*(1-t) + y_151*t**3

x38 = x_152*(1-t)**3 + 3*x_153*t*(1-t)**2 + 3*x_154*t**2*(1-t) + x_155*t**3
y38 = y_152*(1-t)**3 + 3*y_153*t*(1-t)**2 + 3*y_154*t**2*(1-t) + y_155*t**3

x39 = x_156*(1-t)**3 + 3*x_157*t*(1-t)**2 + 3*x_158*t**2*(1-t) + x_159*t**3
y39 = y_156*(1-t)**3 + 3*y_157*t*(1-t)**2 + 3*y_158*t**2*(1-t) + y_159*t**3

x40 = x_160*(1-t)**3 + 3*x_161*t*(1-t)**2 + 3*x_162*t**2*(1-t) + x_163*t**3
y40 = y_160*(1-t)**3 + 3*y_161*t*(1-t)**2 + 3*y_162*t**2*(1-t) + y_163*t**3

x41 = x_164*(1-t)**3 + 3*x_165*t*(1-t)**2 + 3*x_166*t**2*(1-t) + x_167*t**3
y41 = y_164*(1-t)**3 + 3*y_165*t*(1-t)**2 + 3*y_166*t**2*(1-t) + y_167*t**3

x42 = x_168*(1-t)**3 + 3*x_169*t*(1-t)**2 + 3*x_170*t**2*(1-t) + x_171*t**3
y42 = y_168*(1-t)**3 + 3*y_169*t*(1-t)**2 + 3*y_170*t**2*(1-t) + y_171*t**3

x43 = x_172*(1-t)**3 + 3*x_173*t*(1-t)**2 + 3*x_174*t**2*(1-t) + x_175*t**3
y43 = y_172*(1-t)**3 + 3*y_173*t*(1-t)**2 + 3*y_174*t**2*(1-t) + y_175*t**3

x44 = x_176*(1-t)**3 + 3*x_177*t*(1-t)**2 + 3*x_178*t**2*(1-t) + x_179*t**3
y44 = y_176*(1-t)**3 + 3*y_177*t*(1-t)**2 + 3*y_178*t**2*(1-t) + y_179*t**3

x45 = x_180*(1-t)**3 + 3*x_181*t*(1-t)**2 + 3*x_182*t**2*(1-t) + x_183*t**3
y45 = y_180*(1-t)**3 + 3*y_181*t*(1-t)**2 + 3*y_182*t**2*(1-t) + y_183*t**3

x46 = x_184*(1-t)**3 + 3*x_185*t*(1-t)**2 + 3*x_186*t**2*(1-t) + x_187*t**3
y46 = y_184*(1-t)**3 + 3*y_185*t*(1-t)**2 + 3*y_186*t**2*(1-t) + y_187*t**3

x47 = x_188*(1-t)**3 + 3*x_189*t*(1-t)**2 + 3*x_190*t**2*(1-t) + x_191*t**3
y47 = y_188*(1-t)**3 + 3*y_189*t*(1-t)**2 + 3*y_190*t**2*(1-t) + y_191*t**3

x48 = x_192*(1-t)**3 + 3*x_193*t*(1-t)**2 + 3*x_194*t**2*(1-t) + x_195*t**3
y48 = y_192*(1-t)**3 + 3*y_193*t*(1-t)**2 + 3*y_194*t**2*(1-t) + y_195*t**3

x49 = x_196*(1-t)**3 + 3*x_197*t*(1-t)**2 + 3*x_198*t**2*(1-t) + x_199*t**3
y49 = y_196*(1-t)**3 + 3*y_197*t*(1-t)**2 + 3*y_198*t**2*(1-t) + y_199*t**3

x50 = x_200*(1-t)**3 + 3*x_201*t*(1-t)**2 + 3*x_202*t**2*(1-t) + x_203*t**3
y50 = y_200*(1-t)**3 + 3*y_201*t*(1-t)**2 + 3*y_202*t**2*(1-t) + y_203*t**3

x51 = x_204*(1-t)**3 + 3*x_205*t*(1-t)**2 + 3*x_206*t**2*(1-t) + x_207*t**3
y51 = y_204*(1-t)**3 + 3*y_205*t*(1-t)**2 + 3*y_206*t**2*(1-t) + y_207*t**3

x52 = x_208*(1-t)**3 + 3*x_209*t*(1-t)**2 + 3*x_210*t**2*(1-t) + x_211*t**3
y52 = y_208*(1-t)**3 + 3*y_209*t*(1-t)**2 + 3*y_210*t**2*(1-t) + y_211*t**3

x53 = x_212*(1-t)**3 + 3*x_213*t*(1-t)**2 + 3*x_214*t**2*(1-t) + x_215*t**3
y53 = y_212*(1-t)**3 + 3*y_213*t*(1-t)**2 + 3*y_214*t**2*(1-t) + y_215*t**3
 
#x_puntos = [x_0,x_1,x_2,x_3]
#y_puntos = [y_0,y_1,y_2,y_3] 

f = plt.figure()
plt.title('Curva de Bezier') 
plt.xlabel('Eje x') 
plt.ylabel('Eje y') 
f.set_figwidth(25)
f.set_figheight(15)
#plt.plot(x_puntos, y_puntos, color='black', linestyle='-', linewidth = 1, 
         #marker='s', markerfacecolor='black', markersize = 6) 
plt.plot(x,y,color=('#9ADCFF'),lw=4)
plt.plot(x2,y2,color=('#9ADCFF'),lw=4)
plt.plot(x3,y3,color=('#9ADCFF'),lw=4)
plt.plot(x4,y4,color=('#9ADCFF'),lw=4)
plt.plot(x5,y5,color=('#9ADCFF'),lw=4)
plt.plot(x6,y6,color=('#9ADCFF'),lw=4)
plt.plot(x7,y7,color=('#9ADCFF'),lw=4)
plt.plot(x8,y8,color=('#9ADCFF'),lw=4)
plt.plot(x9,y9,color=('#9ADCFF'),lw=4)
plt.plot(x10,y10,color=('#9ADCFF'),lw=4)
plt.plot(x11,y11,color=('#9ADCFF'),lw=4)
plt.plot(x12,y12,color=('#9ADCFF'),lw=4)
plt.plot(x13,y13,color=('#9ADCFF'),lw=4)
plt.plot(x14,y14,color=('#9ADCFF'),lw=4)
plt.plot(x15,y15,color=('#9ADCFF'),lw=4)
plt.plot(x16,y16,color=('#9ADCFF'),lw=4)
plt.plot(x17,y17,color=('#FFF89A'),lw=4)
plt.plot(x18,y18,color=('#FFF89A'),lw=4)
plt.plot(x19,y19,color=('#FFF89A'),lw=4)
plt.plot(x20,y20,color=('#FFF89A'),lw=4)
plt.plot(x21,y21,color=('#FFF89A'),lw=4)
plt.plot(x22,y22,color=('#FFF89A'),lw=4)
plt.plot(x23,y23,color=('#FFF89A'),lw=4)
plt.plot(x24,y24,color=('#FFF89A'),lw=4)
plt.plot(x25,y25,color=('#FFF89A'),lw=4)
plt.plot(x26,y26,color=('#FFF89A'),lw=4)
plt.plot(x27,y27,color=('#FFB2A6'),lw=4)
plt.plot(x28,y28,color=('#FFB2A6'),lw=4)
plt.plot(x29,y29,color=('#FFB2A6'),lw=4)
plt.plot(x30,y30,color=('#FFB2A6'),lw=4)
plt.plot(x31,y31,color=('#FFB2A6'),lw=4)
plt.plot(x32,y32,color=('#FFB2A6'),lw=4)
plt.plot(x33,y33,color=('#FFB2A6'),lw=4)
plt.plot(x34,y34,color=('#FFB2A6'),lw=4)
plt.plot(x35,y35,color=('#FF8AAE'),lw=4)
plt.plot(x36,y36,color=('#FF8AAE'),lw=4)
plt.plot(x37,y37,color=('#FF8AAE'),lw=4)
plt.plot(x38,y38,color=('#FF8AAE'),lw=4)
plt.plot(x39,y39,color=('#FF8AAE'),lw=4)
plt.plot(x40,y40,color=('#FF8AAE'),lw=4)
plt.plot(x41,y41,color=('#FF8AAE'),lw=4)
plt.plot(x42,y42,color=('#FF8AAE'),lw=4)
plt.plot(x43,y43,color=('#FF8AAE'),lw=4)
plt.plot(x44,y44,color=('#FF8AAE'),lw=4)
plt.plot(x45,y45,color=('#FF8AAE'),lw=4)
plt.plot(x46,y46,color=('#FF8AAE'),lw=4)
plt.plot(x47,y47,color=('#FF8AAE'),lw=4)
plt.plot(x48,y48,color=('#FF8AAE'),lw=4)
plt.plot(x49,y49,color=('#FF8AAE'),lw=4)
plt.plot(x50,y50,color=('#FF8AAE'),lw=4)
plt.plot(x51,y51,color=('#FF8AAE'),lw=4)
plt.plot(x52,y52,color=('#FF8AAE'),lw=4)
plt.plot(x53,y53,color=('#FF8AAE'),lw=4)

plt.show()

######
